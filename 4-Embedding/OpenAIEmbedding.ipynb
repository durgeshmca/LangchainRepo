# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = OPEN_API_KEY

# %%
from langchain_community.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
text = "Ths is an example of openai embedding"
query_result = embeddings.embed_query(text)
print(query_result)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 text = "Ths is an example of openai embedding"
# ----> 2 query_result = embeddings.embed_query(text)
#       3 print(query_result)
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:699, in OpenAIEmbeddings.embed_query(self, text)
#     690 def embed_query(self, text: str) -> List[float]:
#     691     """Call out to OpenAI's embedding endpoint for embedding query text.
#     692
#     693     Args:
#    (...)
#     697         Embedding for the text.
#     698     """
# --> 699     return self.embed_documents([text])[0]
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:670, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     667 # NOTE: to keep things simple, we assume the list may contain texts longer
#     668 #       than the maximum context and use length-safe embedding function.
#     669 engine = cast(str, self.deployment)
# --> 670 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:496, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     494 batched_embeddings: List[List[float]] = []
#     495 for i in _iter:
# --> 496     response = embed_with_retry(
#     497         self,
#     498         input=tokens[i : i + _chunk_size],
#     499         **self._invocation_params,
#     500     )
#     501     if not isinstance(response, dict):
#     502         response = response.dict()
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:120, in embed_with_retry(embeddings, **kwargs)
#     118 """Use tenacity to retry the embedding call."""
#     119 if is_openai_v1():
# --> 120     return embeddings.client.create(**kwargs)
#     121 retry_decorator = _create_retry_decorator(embeddings)
#     123 @retry_decorator
#     124 def _embed_with_retry(**kwargs: Any) -> Any:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)
embeddings_1024.embed_query(text)
# Out:
# /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:270: UserWarning: WARNING! dimensions is not default parameter.
#                     dimensions was transferred to model_kwargs.
#                     Please confirm that dimensions is what you intended.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)
# ----> 2 embeddings_1024.embed_query(text)
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:699, in OpenAIEmbeddings.embed_query(self, text)
#     690 def embed_query(self, text: str) -> List[float]:
#     691     """Call out to OpenAI's embedding endpoint for embedding query text.
#     692
#     693     Args:
#    (...)
#     697         Embedding for the text.
#     698     """
# --> 699     return self.embed_documents([text])[0]
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:670, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     667 # NOTE: to keep things simple, we assume the list may contain texts longer
#     668 #       than the maximum context and use length-safe embedding function.
#     669 engine = cast(str, self.deployment)
# --> 670 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:496, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     494 batched_embeddings: List[List[float]] = []
#     495 for i in _iter:
# --> 496     response = embed_with_retry(
#     497         self,
#     498         input=tokens[i : i + _chunk_size],
#     499         **self._invocation_params,
#     500     )
#     501     if not isinstance(response, dict):
#     502         response = response.dict()
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/langchain_community/embeddings/openai.py:120, in embed_with_retry(embeddings, **kwargs)
#     118 """Use tenacity to retry the embedding call."""
#     119 if is_openai_v1():
# --> 120     return embeddings.client.create(**kwargs)
#     121 retry_decorator = _create_retry_decorator(embeddings)
#     123 @retry_decorator
#     124 def _embed_with_retry(**kwargs: Any) -> Any:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File /official/official_docs/PythonLearning/GenerativeAIWithLangchainByKrish/projects/venv/lib/python3.10/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
